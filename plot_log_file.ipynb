# %%
fid = open("G:/My Drive/01runs/out-BlindSIM-20200811-collection/out-BlindSIM-256-nframe100-20200810/log.txt",'r')


psnrlist = []
ssimlist = []

for line in fid:
    if 'sr: ' in line:
        psnrlist.append(float(line.split('sr: ')[1].split(' dB')[0]))
        ssimlist.append(float(line.split('sr: ')[1].split(' dB / ')[1]))

# %%
import matplotlib.pyplot as plt
plt.plot(psnrlist)

# %%
plt.plot(ssimlist)
