# %%
from PIL import Image
import skimage.io

# %%
img1 = skimage.io.imread("G:/My Drive/01datasets/Meng/segmentation 210920/u18666a/TFEB488 ER561 LYSOT640 U18666A1.cxd-fairSIM-1.png")
img2 = Image.open("G:/My Drive/01datasets/Meng/segmentation 210920/u18666a/TFEB488 ER561 LYSOT640 U18666A1.cxd-fairSIM-1.png")

# %%
img1.shape
# Out:
# (1024, 1024, 4)

# %%
import numpy as np
np.array(img2).shape
# Out:
# (1024, 1024)

# %%
import matplotlib.pyplot as plt
plt.imshow(np.mean(img1,axis=2),cmap='gray')
plt.colorbar()

# %%
plt.imshow(np.array(img2),cmap='gray')
plt.colorbar()

# %%
img = skimage.io.imread("G:/My Drive/01datasets/Meng/segmentation 2020_10_02/LRRK MBCD/MITOCELIA488 ERAPPLE561 LYSOTRACKER640 LRRK2 MBCD1.cxd-fairSIM-1.tif")

# %%
import numpy as np
np.max(img)

import skimage.exposure

np.max(skimage.exposure.rescale_intensity(img.astype('float'),in_range=(0,255)))
# Out:
# 1.0
